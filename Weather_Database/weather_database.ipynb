# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 763

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data. 

city_data = []

#Print the beginning of the logging. 
print('Beginning Data Retrieval     ')
print('-----------------------------')

#Create counters. 
record_count = 1 
set_count = 1

#Looping through all the cities in our list. 

for i,city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. 
    city_url = url + '&q=' + city.replace(' ','+')

    #Log the URL, record, and set numbers and the city. 
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    #Add 1 to the record count. 
    record_count += 1

    #Run an API 

    try:
        #Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        #Parse out the needed data. 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather ['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        #Append the city information into the city_data list. 
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat, 
                        "Lng": city_lng, 
                        "Max Temp": city_max_temp, 
                        "Humidity": city_humidity, 
                        "Cloudiness": city_clouds, 
                        "Wind Speed": city_wind,
                        "Current Description": city_description})
        #If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass

#Indicate the Data loading is complete
print('---------------------------')
print('Data Retrieval Complete    ')
print('---------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | malkara
# Processing Record 13 of Set 1 | tigzirt
# Processing Record 14 of Set 1 | solton
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 1 | gravdal
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | anadyr
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | buta
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | belyy yar
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | dubai
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | la reforma
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | maceio
# Processing Record 46 of Set 1 | rapid valley
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | karratha
# Processing Record 49 of Set 1 | taos
# Processing Record 50 of Set 1 | le moule
# Processing Record 1 of Set 2 | sitka
# Processing Record 2 of Set 2 | taperoa
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | caravelas
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | tortoli
# Processing Record 10 of Set 2 | mizan teferi
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | hohhot
# Processing Record 13 of Set 2 | hamilton
# Processing Record 14 of Set 2 | havelock
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | mildura
# Processing Record 17 of Set 2 | villa maria
# Processing Record 18 of Set 2 | senneterre
# Processing Record 19 of Set 2 | adrar
# Processing Record 20 of Set 2 | iraray
# Processing Record 21 of Set 2 | gorontalo
# Processing Record 22 of Set 2 | andros town
# Processing Record 23 of Set 2 | farah
# Processing Record 24 of Set 2 | gryazovets
# Processing Record 25 of Set 2 | honiara
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 2 | grua
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | vostok
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | kem
# Processing Record 33 of Set 2 | bilibino
# Processing Record 34 of Set 2 | jaisinghnagar
# Processing Record 35 of Set 2 | mindelo
# Processing Record 36 of Set 2 | miri
# Processing Record 37 of Set 2 | san policarpo
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | hecun
# Processing Record 44 of Set 2 | sokolka
# Processing Record 45 of Set 2 | kuminskiy
# Processing Record 46 of Set 2 | kochi
# Processing Record 47 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 2 | kota belud
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | kyra
# Processing Record 1 of Set 3 | kyren
# Processing Record 2 of Set 3 | szczytno
# Processing Record 3 of Set 3 | port blair
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | jocotepec
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | kaseda
# Processing Record 10 of Set 3 | linhares
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | derzhavinsk
# Processing Record 16 of Set 3 | magadan
# Processing Record 17 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | matara
# Processing Record 20 of Set 3 | muborak
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | abu dhabi
# Processing Record 23 of Set 3 | jiuquan
# Processing Record 24 of Set 3 | la rochelle
# Processing Record 25 of Set 3 | tautira
# Processing Record 26 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 3 | wanning
# Processing Record 28 of Set 3 | zhigansk
# Processing Record 29 of Set 3 | brae
# Processing Record 30 of Set 3 | novokayakent
# Processing Record 31 of Set 3 | belokurikha
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | hit
# Processing Record 35 of Set 3 | svobodnyy
# Processing Record 36 of Set 3 | melnik
# Processing Record 37 of Set 3 | fare
# Processing Record 38 of Set 3 | rongcheng
# Processing Record 39 of Set 3 | solnechnyy
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | kununurra
# Processing Record 42 of Set 3 | dangriga
# Processing Record 43 of Set 3 | meulaboh
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | sumter
# Processing Record 47 of Set 3 | abnub
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 3 | moses lake
# Processing Record 1 of Set 4 | marawi
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | neuquen
# Processing Record 4 of Set 4 | apricena
# Processing Record 5 of Set 4 | matay
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | amuntai
# Processing Record 8 of Set 4 | cururupu
# Processing Record 9 of Set 4 | pala
# Processing Record 10 of Set 4 | kytlym
# City not found. Skipping...
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | vero beach
# Processing Record 13 of Set 4 | kijang
# Processing Record 14 of Set 4 | anzio
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | rawson
# Processing Record 18 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 4 | hambantota
# Processing Record 20 of Set 4 | ugoofaaru
# Processing Record 21 of Set 4 | grand gaube
# Processing Record 22 of Set 4 | tilichiki
# Processing Record 23 of Set 4 | fereydunshahr
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | padang
# Processing Record 28 of Set 4 | atar
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | karimganj
# Processing Record 31 of Set 4 | namatanai
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | sfantu gheorghe
# Processing Record 34 of Set 4 | champaign
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | kalmunai
# Processing Record 37 of Set 4 | alta gracia
# Processing Record 38 of Set 4 | at-bashi
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | atuona
# Processing Record 41 of Set 4 | husavik
# Processing Record 42 of Set 4 | caohe
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | danilov
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | saint-denis
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | bandarbeyla
# Processing Record 50 of Set 4 | vanimo
# Processing Record 1 of Set 5 | berdsk
# Processing Record 2 of Set 5 | tura
# Processing Record 3 of Set 5 | ahipara
# Processing Record 4 of Set 5 | vardo
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | pilar
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | vestmannaeyjar
# Processing Record 10 of Set 5 | samarai
# Processing Record 11 of Set 5 | shelburne
# Processing Record 12 of Set 5 | aklavik
# Processing Record 13 of Set 5 | varkaus
# Processing Record 14 of Set 5 | evensk
# Processing Record 15 of Set 5 | yumen
# Processing Record 16 of Set 5 | souillac
# Processing Record 17 of Set 5 | marsa matruh
# Processing Record 18 of Set 5 | valdivia
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | caldwell
# Processing Record 21 of Set 5 | prosyana
# City not found. Skipping...
# Processing Record 22 of Set 5 | balkhash
# Processing Record 23 of Set 5 | grindavik
# Processing Record 24 of Set 5 | prince rupert
# Processing Record 25 of Set 5 | sawtell
# Processing Record 26 of Set 5 | bhind
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | henties bay
# Processing Record 29 of Set 5 | sao jose da coroa grande
# Processing Record 30 of Set 5 | krasnoye
# Processing Record 31 of Set 5 | sola
# Processing Record 32 of Set 5 | temozon
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | skjervoy
# Processing Record 35 of Set 5 | camalu
# Processing Record 36 of Set 5 | wajir
# Processing Record 37 of Set 5 | alice town
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | darab
# Processing Record 41 of Set 5 | malazgirt
# Processing Record 42 of Set 5 | nantucket
# Processing Record 43 of Set 5 | ribeira grande
# Processing Record 44 of Set 5 | karakol
# Processing Record 45 of Set 5 | kawalu
# Processing Record 46 of Set 5 | vila velha
# Processing Record 47 of Set 5 | ankang
# Processing Record 48 of Set 5 | aykhal
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | peru
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | chiredzi
# Processing Record 4 of Set 6 | aswan
# Processing Record 5 of Set 6 | osijek
# Processing Record 6 of Set 6 | suchiate
# Processing Record 7 of Set 6 | zhangjiakou
# Processing Record 8 of Set 6 | auce
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | hekinan
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | pailon
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | slave lake
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | mpwapwa
# Processing Record 17 of Set 6 | broken hill
# Processing Record 18 of Set 6 | lydenburg
# Processing Record 19 of Set 6 | tessalit
# Processing Record 20 of Set 6 | pedro ii
# Processing Record 21 of Set 6 | lensk
# Processing Record 22 of Set 6 | bac lieu
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | innisfail
# Processing Record 27 of Set 6 | kerema
# Processing Record 28 of Set 6 | smoky lake
# Processing Record 29 of Set 6 | la seyne-sur-mer
# Processing Record 30 of Set 6 | zinder
# Processing Record 31 of Set 6 | takoradi
# Processing Record 32 of Set 6 | moissac
# Processing Record 33 of Set 6 | moose factory
# Processing Record 34 of Set 6 | tamluk
# Processing Record 35 of Set 6 | ust-maya
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | kunda
# Processing Record 38 of Set 6 | aldan
# Processing Record 39 of Set 6 | fort nelson
# Processing Record 40 of Set 6 | santo domingo
# Processing Record 41 of Set 6 | arlit
# Processing Record 42 of Set 6 | acapulco
# Processing Record 43 of Set 6 | salto
# Processing Record 44 of Set 6 | bulgan
# Processing Record 45 of Set 6 | gaziantep
# Processing Record 46 of Set 6 | faya
# Processing Record 47 of Set 6 | san joaquin
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 50 of Set 6 | micheweni
# Processing Record 1 of Set 7 | carlisle
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | seoul
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | sechura
# Processing Record 6 of Set 7 | maria la baja
# Processing Record 7 of Set 7 | usinsk
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | tigil
# Processing Record 10 of Set 7 | kasongo
# Processing Record 11 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 7 | sile
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | qandala
# Processing Record 15 of Set 7 | yar-sale
# Processing Record 16 of Set 7 | araouane
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | beringovskiy
# Processing Record 19 of Set 7 | portland
# Processing Record 20 of Set 7 | malakal
# Processing Record 21 of Set 7 | sisimiut
# Processing Record 22 of Set 7 | banda aceh
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | niteroi
# Processing Record 25 of Set 7 | vao
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | paamiut
# Processing Record 28 of Set 7 | axim
# Processing Record 29 of Set 7 | coihaique
# Processing Record 30 of Set 7 | maniitsoq
# Processing Record 31 of Set 7 | rio grande
# Processing Record 32 of Set 7 | tazovskiy
# Processing Record 33 of Set 7 | gornopravdinsk
# Processing Record 34 of Set 7 | baykit
# Processing Record 35 of Set 7 | fairfield
# Processing Record 36 of Set 7 | labuhan
# Processing Record 37 of Set 7 | sorland
# Processing Record 38 of Set 7 | uniara
# Processing Record 39 of Set 7 | lavrentiya
# Processing Record 40 of Set 7 | ossora
# Processing Record 41 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 7 | vallenar
# Processing Record 43 of Set 7 | toungoo
# City not found. Skipping...
# Processing Record 44 of Set 7 | talcahuano
# Processing Record 45 of Set 7 | la romana
# Processing Record 46 of Set 7 | tianpeng
# Processing Record 47 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 7 | bethel
# Processing Record 49 of Set 7 | kasongo-lunda
# Processing Record 50 of Set 7 | shakawe
# Processing Record 1 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 2 of Set 8 | katsuura
# Processing Record 3 of Set 8 | kruisfontein
# Processing Record 4 of Set 8 | kerman
# Processing Record 5 of Set 8 | sakakah
# Processing Record 6 of Set 8 | oriximina
# Processing Record 7 of Set 8 | palmer
# Processing Record 8 of Set 8 | south lake tahoe
# Processing Record 9 of Set 8 | makakilo city
# Processing Record 10 of Set 8 | nizwa
# Processing Record 11 of Set 8 | ostrovnoy
# Processing Record 12 of Set 8 | kushchevskaya
# Processing Record 13 of Set 8 | megion
# Processing Record 14 of Set 8 | paralimni
# Processing Record 15 of Set 8 | jiwani
# Processing Record 16 of Set 8 | haines junction
# Processing Record 17 of Set 8 | nanakuli
# Processing Record 18 of Set 8 | altamira
# Processing Record 19 of Set 8 | lahat
# Processing Record 20 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 8 | naze
# Processing Record 22 of Set 8 | half moon bay
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | les cayes
# Processing Record 26 of Set 8 | chicama
# Processing Record 27 of Set 8 | mezen
# Processing Record 28 of Set 8 | sangar
# Processing Record 29 of Set 8 | harper
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 8 | pokrovskoye
# Processing Record 33 of Set 8 | mossendjo
# Processing Record 34 of Set 8 | cooma
# Processing Record 35 of Set 8 | high level
# Processing Record 36 of Set 8 | san francisco
# Processing Record 37 of Set 8 | loviisa
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | tuktoyaktuk
# Processing Record 40 of Set 8 | itoman
# Processing Record 41 of Set 8 | elat
# Processing Record 42 of Set 8 | mosquera
# Processing Record 43 of Set 8 | cockburn town
# Processing Record 44 of Set 8 | katima mulilo
# Processing Record 45 of Set 8 | sao raimundo nonato
# Processing Record 46 of Set 8 | chara
# Processing Record 47 of Set 8 | bubaque
# Processing Record 48 of Set 8 | suez
# Processing Record 49 of Set 8 | vrangel
# Processing Record 50 of Set 8 | puerto suarez
# Processing Record 1 of Set 9 | gurupa
# Processing Record 2 of Set 9 | shenjiamen
# Processing Record 3 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 9 | marquette
# Processing Record 5 of Set 9 | santa maria
# Processing Record 6 of Set 9 | tiksi
# Processing Record 7 of Set 9 | oliveira do hospital
# Processing Record 8 of Set 9 | lamu
# Processing Record 9 of Set 9 | nadym
# Processing Record 10 of Set 9 | esperance
# Processing Record 11 of Set 9 | dekoa
# City not found. Skipping...
# Processing Record 12 of Set 9 | sorada
# Processing Record 13 of Set 9 | dunedin
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | sal rei
# Processing Record 17 of Set 9 | mahon
# Processing Record 18 of Set 9 | antsohihy
# Processing Record 19 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 9 | nouadhibou
# Processing Record 21 of Set 9 | hualmay
# Processing Record 22 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 9 | lander
# Processing Record 24 of Set 9 | roberto payan
# City not found. Skipping...
# Processing Record 25 of Set 9 | djambala
# Processing Record 26 of Set 9 | torun
# Processing Record 27 of Set 9 | siddipet
# Processing Record 28 of Set 9 | talara
# Processing Record 29 of Set 9 | gao
# Processing Record 30 of Set 9 | basoko
# Processing Record 31 of Set 9 | acajutla
# Processing Record 32 of Set 9 | north platte
# Processing Record 33 of Set 9 | saint anthony
# Processing Record 34 of Set 9 | iida
# Processing Record 35 of Set 9 | lulea
# Processing Record 36 of Set 9 | turmalina
# Processing Record 37 of Set 9 | north bend
# Processing Record 38 of Set 9 | nortelandia
# Processing Record 39 of Set 9 | dole
# Processing Record 40 of Set 9 | razgrad
# Processing Record 41 of Set 9 | tazmalt
# Processing Record 42 of Set 9 | riyadh
# Processing Record 43 of Set 9 | baghdad
# Processing Record 44 of Set 9 | okha
# Processing Record 45 of Set 9 | sobolevo
# Processing Record 46 of Set 9 | forio
# Processing Record 47 of Set 9 | asfi
# Processing Record 48 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | gonbad-e qabus
# Processing Record 50 of Set 9 | anloga
# Processing Record 1 of Set 10 | qaqortoq
# Processing Record 2 of Set 10 | chesma
# Processing Record 3 of Set 10 | capreol
# Processing Record 4 of Set 10 | casablanca
# Processing Record 5 of Set 10 | trinidad
# Processing Record 6 of Set 10 | novikovo
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | jardim
# Processing Record 9 of Set 10 | chokurdakh
# Processing Record 10 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 10 | kaeo
# Processing Record 12 of Set 10 | tumut
# Processing Record 13 of Set 10 | vagur
# Processing Record 14 of Set 10 | maumere
# Processing Record 15 of Set 10 | novyy urengoy
# Processing Record 16 of Set 10 | barreiras
# Processing Record 17 of Set 10 | suntar
# Processing Record 18 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | kachug
# Processing Record 22 of Set 10 | mathathane
# Processing Record 23 of Set 10 | mikkeli
# Processing Record 24 of Set 10 | kropotkin
# Processing Record 25 of Set 10 | fortuna
# Processing Record 26 of Set 10 | wiarton
# Processing Record 27 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | sovetskiy
# Processing Record 29 of Set 10 | atasu
# Processing Record 30 of Set 10 | podor
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | corrales
# Processing Record 33 of Set 10 | yatou
# Processing Record 34 of Set 10 | qiongshan
# Processing Record 35 of Set 10 | liptovsky hradok
# Processing Record 36 of Set 10 | saint-pierre
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | gizo
# Processing Record 39 of Set 10 | falkenberg
# Processing Record 40 of Set 10 | libreville
# Processing Record 41 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 42 of Set 10 | esenyurt
# Processing Record 43 of Set 10 | black river
# Processing Record 44 of Set 10 | charallave
# Processing Record 45 of Set 10 | crestview
# Processing Record 46 of Set 10 | semey
# Processing Record 47 of Set 10 | nanortalik
# Processing Record 48 of Set 10 | college
# Processing Record 49 of Set 10 | athabasca
# Processing Record 50 of Set 10 | tomohon
# Processing Record 1 of Set 11 | yerbogachen
# Processing Record 2 of Set 11 | ponta delgada
# Processing Record 3 of Set 11 | mana
# Processing Record 4 of Set 11 | angoche
# Processing Record 5 of Set 11 | isiro
# Processing Record 6 of Set 11 | roura
# Processing Record 7 of Set 11 | yangambi
# Processing Record 8 of Set 11 | nagornyy
# Processing Record 9 of Set 11 | lerwick
# Processing Record 10 of Set 11 | bridlington
# Processing Record 11 of Set 11 | aquiraz
# Processing Record 12 of Set 11 | roald
# Processing Record 13 of Set 11 | santa rosa
# Processing Record 14 of Set 11 | dukat
# Processing Record 15 of Set 11 | kefalos
# Processing Record 16 of Set 11 | jackson
# Processing Record 17 of Set 11 | zaysan
# Processing Record 18 of Set 11 | ozinki
# Processing Record 19 of Set 11 | laredo
# Processing Record 20 of Set 11 | dawei
# Processing Record 21 of Set 11 | ullapool
# Processing Record 22 of Set 11 | mangrol
# Processing Record 23 of Set 11 | plainview
# Processing Record 24 of Set 11 | tacuarembo
# Processing Record 25 of Set 11 | pitimbu
# Processing Record 26 of Set 11 | san jose
# Processing Record 27 of Set 11 | touros
# Processing Record 28 of Set 11 | varhaug
# Processing Record 29 of Set 11 | te anau
# Processing Record 30 of Set 11 | kenai
# Processing Record 31 of Set 11 | pedro juan caballero
# Processing Record 32 of Set 11 | churachandpur
# Processing Record 33 of Set 11 | saint-augustin
# Processing Record 34 of Set 11 | lorengau
# Processing Record 35 of Set 11 | belaya gora
# Processing Record 36 of Set 11 | kichera
# Processing Record 37 of Set 11 | laja
# Processing Record 38 of Set 11 | aguas verdes
# Processing Record 39 of Set 11 | manta
# Processing Record 40 of Set 11 | necochea
# Processing Record 41 of Set 11 | salamanca
# Processing Record 42 of Set 11 | kirakira
# Processing Record 43 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 44 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 11 | lyaskelya
# Processing Record 46 of Set 11 | turtas
# Processing Record 47 of Set 11 | kodinsk
# Processing Record 48 of Set 11 | barauna
# Processing Record 49 of Set 11 | kutum
# Processing Record 50 of Set 11 | tashara
# Processing Record 1 of Set 12 | macas
# Processing Record 2 of Set 12 | thiruvananthapuram
# Processing Record 3 of Set 12 | khowst
# Processing Record 4 of Set 12 | sarangani
# Processing Record 5 of Set 12 | egvekinot
# Processing Record 6 of Set 12 | ladybrand
# Processing Record 7 of Set 12 | kimbe
# Processing Record 8 of Set 12 | taltal
# Processing Record 9 of Set 12 | tarija
# Processing Record 10 of Set 12 | san cristobal
# Processing Record 11 of Set 12 | horsham
# Processing Record 12 of Set 12 | mount isa
# Processing Record 13 of Set 12 | birjand
# Processing Record 14 of Set 12 | frankfort
# Processing Record 15 of Set 12 | taoudenni
# Processing Record 16 of Set 12 | riberalta
# Processing Record 17 of Set 12 | tuatapere
# Processing Record 18 of Set 12 | camocim
# Processing Record 19 of Set 12 | phnum penh
# City not found. Skipping...
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | santiago del estero
# Processing Record 22 of Set 12 | novoilinsk
# Processing Record 23 of Set 12 | izumo
# Processing Record 24 of Set 12 | zeya
# Processing Record 25 of Set 12 | el cobre
# Processing Record 26 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 12 | kalemie
# Processing Record 29 of Set 12 | melilla
# Processing Record 30 of Set 12 | blagoyevo
# Processing Record 31 of Set 12 | malatya
# Processing Record 32 of Set 12 | sogdiondon
# City not found. Skipping...
# Processing Record 33 of Set 12 | sangin
# Processing Record 34 of Set 12 | mayo
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | thyboron
# Processing Record 37 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 38 of Set 12 | kirkland lake
# Processing Record 39 of Set 12 | vyskov
# Processing Record 40 of Set 12 | saint george
# Processing Record 41 of Set 12 | batavia
# Processing Record 42 of Set 12 | severomuysk
# Processing Record 43 of Set 12 | beloha
# Processing Record 44 of Set 12 | sao felix do xingu
# Processing Record 45 of Set 12 | emporia
# Processing Record 46 of Set 12 | chandvad
# Processing Record 47 of Set 12 | kant
# Processing Record 48 of Set 12 | gorele
# Processing Record 49 of Set 12 | bonavista
# Processing Record 50 of Set 12 | charyshskoye
# Processing Record 1 of Set 13 | buraydah
# Processing Record 2 of Set 13 | coquimbo
# Processing Record 3 of Set 13 | la ronge
# Processing Record 4 of Set 13 | bagdarin
# Processing Record 5 of Set 13 | kedrovyy
# Processing Record 6 of Set 13 | khani
# Processing Record 7 of Set 13 | sibiti
# Processing Record 8 of Set 13 | ayr
# Processing Record 9 of Set 13 | kupino
# Processing Record 10 of Set 13 | sabana de torres
# Processing Record 11 of Set 13 | brisbane
# Processing Record 12 of Set 13 | jamame
# Processing Record 13 of Set 13 | nouakchott
# Processing Record 14 of Set 13 | santa maria da vitoria
# Processing Record 15 of Set 13 | bingol
# Processing Record 16 of Set 13 | antigonish
# Processing Record 17 of Set 13 | santa cruz
# Processing Record 18 of Set 13 | helong
# Processing Record 19 of Set 13 | pontes e lacerda
# Processing Record 20 of Set 13 | kandi
# Processing Record 21 of Set 13 | nelson bay
# Processing Record 22 of Set 13 | iasmos
# Processing Record 23 of Set 13 | acaponeta
# Processing Record 24 of Set 13 | leh
# Processing Record 25 of Set 13 | jiaocheng
# Processing Record 26 of Set 13 | camopi
# Processing Record 27 of Set 13 | de aar
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | brunico
# Processing Record 30 of Set 13 | fairbanks
# Processing Record 31 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 13 | rincon
# Processing Record 33 of Set 13 | mandali
# Processing Record 34 of Set 13 | praia da vitoria
# Processing Record 35 of Set 13 | torbat-e jam
# Processing Record 36 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 13 | ulaangom
# Processing Record 38 of Set 13 | macherla
# Processing Record 39 of Set 13 | kaoma
# Processing Record 40 of Set 13 | merrill
# Processing Record 41 of Set 13 | hervey bay
# Processing Record 42 of Set 13 | darlawn
# Processing Record 43 of Set 13 | schwaigern
# Processing Record 44 of Set 13 | honningsvag
# Processing Record 45 of Set 13 | bodden town
# Processing Record 46 of Set 13 | carballo
# Processing Record 47 of Set 13 | along
# Processing Record 48 of Set 13 | mandurah
# Processing Record 49 of Set 13 | cranbrook
# Processing Record 50 of Set 13 | port macquarie
# Processing Record 1 of Set 14 | mattawa
# Processing Record 2 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | karatau
# Processing Record 5 of Set 14 | pappayiannis
# Processing Record 6 of Set 14 | havoysund
# Processing Record 7 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 14 | pacific grove
# Processing Record 9 of Set 14 | lieksa
# Processing Record 10 of Set 14 | abu samrah
# Processing Record 11 of Set 14 | port hedland
# Processing Record 12 of Set 14 | lubumbashi
# Processing Record 13 of Set 14 | tezu
# Processing Record 14 of Set 14 | noumea
# Processing Record 15 of Set 14 | guanica
# Processing Record 16 of Set 14 | jalu
# Processing Record 17 of Set 14 | udachnyy
# Processing Record 18 of Set 14 | kantunilkin
# Processing Record 19 of Set 14 | concepcion
# Processing Record 20 of Set 14 | mineros
# Processing Record 21 of Set 14 | camana
# Processing Record 22 of Set 14 | andenes
# Processing Record 23 of Set 14 | uri
# Processing Record 24 of Set 14 | gdov
# Processing Record 25 of Set 14 | mayumba
# Processing Record 26 of Set 14 | anaconda
# Processing Record 27 of Set 14 | santa fe
# Processing Record 28 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 14 | asau
# Processing Record 30 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 14 | puerto quijarro
# Processing Record 32 of Set 14 | nara
# Processing Record 33 of Set 14 | iskilip
# Processing Record 34 of Set 14 | la macarena
# Processing Record 35 of Set 14 | bakchar
# Processing Record 36 of Set 14 | emba
# Processing Record 37 of Set 14 | santa isabel do rio negro
# Processing Record 38 of Set 14 | weihai
# Processing Record 39 of Set 14 | namtsy
# Processing Record 40 of Set 14 | kloulklubed
# Processing Record 41 of Set 14 | sorokino
# Processing Record 42 of Set 14 | mao
# Processing Record 43 of Set 14 | niscemi
# Processing Record 44 of Set 14 | bud
# Processing Record 45 of Set 14 | himare
# Processing Record 46 of Set 14 | camacha
# Processing Record 47 of Set 14 | burnie
# Processing Record 48 of Set 14 | porterville
# Processing Record 49 of Set 14 | severnyy
# Processing Record 50 of Set 14 | basco
# Processing Record 1 of Set 15 | karlshamn
# Processing Record 2 of Set 15 | alice springs
# Processing Record 3 of Set 15 | silikatnyy
# Processing Record 4 of Set 15 | san roque
# Processing Record 5 of Set 15 | mandera
# Processing Record 6 of Set 15 | abha
# Processing Record 7 of Set 15 | ixtapa
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | tikrit
# Processing Record 10 of Set 15 | maragogi
# Processing Record 11 of Set 15 | serov
# Processing Record 12 of Set 15 | korla
# Processing Record 13 of Set 15 | alyangula
# Processing Record 14 of Set 15 | bairiki
# Processing Record 15 of Set 15 | bonfim
# Processing Record 16 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 15 | paka
# Processing Record 18 of Set 15 | aksarka
# Processing Record 19 of Set 15 | saint-joseph
# Processing Record 20 of Set 15 | kurilsk
# Processing Record 21 of Set 15 | thinadhoo
# Processing Record 22 of Set 15 | santa rosalia
# Processing Record 23 of Set 15 | itarema
# Processing Record 24 of Set 15 | visnes
# Processing Record 25 of Set 15 | catamarca
# Processing Record 26 of Set 15 | wagga wagga
# Processing Record 27 of Set 15 | ankazoabo
# Processing Record 28 of Set 15 | tual
# Processing Record 29 of Set 15 | puerto cabello
# Processing Record 30 of Set 15 | sindor
# Processing Record 31 of Set 15 | point pleasant
# Processing Record 32 of Set 15 | sistranda
# Processing Record 33 of Set 15 | carutapera
# Processing Record 34 of Set 15 | burica
# City not found. Skipping...
# Processing Record 35 of Set 15 | damghan
# Processing Record 36 of Set 15 | yaan
# Processing Record 37 of Set 15 | mulege
# Processing Record 38 of Set 15 | lima
# Processing Record 39 of Set 15 | kelvington
# Processing Record 40 of Set 15 | berbera
# Processing Record 41 of Set 15 | bend
# Processing Record 42 of Set 15 | jalpan
# Processing Record 43 of Set 15 | contamana
# Processing Record 44 of Set 15 | mehamn
# Processing Record 45 of Set 15 | panzhihua
# Processing Record 46 of Set 15 | gumla
# Processing Record 47 of Set 15 | roros
# Processing Record 48 of Set 15 | ikryanoye
# Processing Record 49 of Set 15 | liyang
# Processing Record 50 of Set 15 | laguna
# Processing Record 1 of Set 16 | kautokeino
# Processing Record 2 of Set 16 | belle glade
# Processing Record 3 of Set 16 | tonantins
# Processing Record 4 of Set 16 | manowa
# Processing Record 5 of Set 16 | abidjan
# Processing Record 6 of Set 16 | quatre cocos
# Processing Record 7 of Set 16 | sept-iles
# Processing Record 8 of Set 16 | porto tolle
# Processing Record 9 of Set 16 | mazurivka
# Processing Record 10 of Set 16 | guasdualito
# Processing Record 11 of Set 16 | srikakulam
# Processing Record 12 of Set 16 | aden
# Processing Record 13 of Set 16 | khargone
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     72.16        78          15
# 1  Puerto Ayora      EC  -0.7393  -90.3518     72.55        98          24
# 2   Yellowknife      CA  62.4560 -114.3525     46.92        71          75
# 3         Kapaa      US  22.0752 -159.3190     84.18        71          40
# 4     Busselton      AU -33.6500  115.3333     61.05        59          51
#
#    Wind Speed Current Description
# 0        3.76          few clouds
# 1        9.19          few clouds
# 2        1.99       broken clouds
# 3        4.00    scattered clouds
# 4        9.46       broken clouds

# %%
output_data_file = 'WeatherPy_Database.csv'

# %%
city_data_df.to_csv(output_data_file, index_label='City_ID')
